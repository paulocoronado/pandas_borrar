# %% [markdown]
# <a href="https://colab.research.google.com/github/paulocoronado/pandas_borrar/blob/main/pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Crear una serie
# Arreglo unidimensional de datos

# %%
miSerie= pd.Series([34,56,78,23,34])
miSerie
# Out:
# 0    34
# 1    56
# 2    78
# 3    23
# 4    34
# dtype: int64

# %% [markdown]
# # Diccionarios en Python
#
# Estructura que guarda datos en forma de objetos llave - valor

# %%
miDiccionario={
    "nombre": "Casa1",
    "área": 120,
    "baños": 3,
    "propietarios": [
        "Paulo", "Diana", "Sonia"
    ],
    "barrio": {
        "nombre": "Gran Britalia",
        "localidad": "Bosa"
    }
}

miDiccionario
# Out:
# {'nombre': 'Casa1',
#  'área': 120,
#  'baños': 3,
#  'propietarios': ['Paulo', 'Diana', 'Sonia'],
#  'barrio': {'nombre': 'Gran Britalia', 'localidad': 'Bosa'}}

# %% [markdown]
# # Dataframe
# Estructura de datos en formato tabla.
#
# La forma "simple" de crear un dataframe es a partir de un diccionario, otra forma puede ser desde hojas de cálculo, desde archivos JSON o desde archivos CSV (Valores separados por coma)

# %%
miDataframe= pd.DataFrame({'Si':[10,15], 'No':[50, 68]})
miDataframe
# Out:
#    Si  No
# 0  10  50
# 1  15  68

# %% [markdown]
# Otro Dataframe

# %%
encuesta= pd.DataFrame(
    {
        "Julia": ["me gustó", "Fue horrible"],
        "Pedro": ["Fue delicioso", "No estuvo mal"],
    },
    index=["Restaurante_1", "Restaurante_2"]
)
encuesta
# Out:
#                       Julia          Pedro
# Restaurante_1      me gustó  Fue delicioso
# Restaurante_2  Fue horrible  No estuvo mal

# %% [markdown]
# # Cargar archivos CSV en un dataframe

# %%
# Leer el archivo CSV
miCSV= pd.read_csv("datos.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiante_1   Estudiante_2   Estudiante_3
# 0            34             23             45
# 1            45             10             46
# 2            25             30             46

# %%
miTitanic= pd.read_csv("titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
